# %% [markdown]
# # assignemnts

# %%
# Create a list of items
cart = ["apple", "banana", "milk", "bread", "egg"]


item = input("Enter an item: ")

# Checking  item  in  cart
if item in cart:
    print("Item available")
else:
    print("Sorry, not available")
# Out:
# Enter an item: apple
# Item available

# %% [markdown]
# code 2

# %%
scores = (85, 90, 78, 92, 88, 76)


highest = max(scores)
lowest = min(scores)


average = sum(scores) / len(scores)


print("Highest Score:", highest)
print("Lowest Score:", lowest)
print("Average Score:", round(average, 2))
# Out:
# Highest Score: 92
# Lowest Score: 76
# Average Score: 84.83

# %% [markdown]
# code 3

# %%
visitors = [101, 102, 103, 101, 104, 102, 105, 106, 105]


unique_visitors = set(visitors)


print("Unique Visitors:", unique_visitors)
print("Total Number of Unique Visitors:", len(unique_visitors))
# Out:
# Unique Visitors: {101, 102, 103, 104, 105, 106}
# Total Number of Unique Visitors: 6

# %% [markdown]
# code 4

# %%
students = {"Alice": 85, "Bob": 78, "Charlie": 92}


top_student = max(students, key=students.get)
top_marks = students[top_student]

print("Top Student:", top_student, "with", top_marks, "marks")


name = input("Enter a student name: ")

if name in students:
    print(name, "scored", students[name])
else:
    print("Student not found")
# Out:
# Top Student: Charlie with 92 marks
# Enter a student name: samin
# Student not found

# %% [markdown]
# code 5

# %%
fruits = {"Alice": "Apple", "Bob": "Banana", "Charlie": "Grapes"}


for student, fruit in fruits.items():
    print(student, "likes", fruit)


fruits["David"] = "Mango"
print("\nNew student added: David likes Mango")


name = input("Enter a student name: ")

if name in fruits:
    print(name, "likes", fruits[name])
else:
    print("Student not found")
# Out:
# Alice likes Apple
# Bob likes Banana
# Charlie likes Grapes
#
# New student added: David likes Mango
# Enter a student name: alice
# Student not found
