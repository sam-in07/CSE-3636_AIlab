# %% [markdown]
# **Hill Climbing Algorithm Implementation for 8 Queen Problem in Python**
#
# Artificial Intelligence Lab
#
# Course Code- CSE-3636
#
# Instructor: Muhammad Mubinur Rahman, Assistant Lecturer, Dept. of CSE, IIUC
#
# Teaching Assistant: Al Fahad, 7th Semester, IIUC

# %% [markdown]
# **Simple Hill Climbing Algorithm**

# %%
import random

class EightQueens:
    def __init__(self):
        # Initialize the board with one queen in each row, placed randomly in one of the columns.
        self.board = [random.randint(0, 7) for _ in range(8)]

    def print_board(self):
        # Print the board for visualization
        for row in range(8):
            line = ""
            for col in range(8):
                if self.board[row] == col:
                    line += "Q "
                else:
                    line += ". "
            print(line)
        print()

    def calculate_conflicts(self, board):
        # Calculate the number of conflicts (queens attacking each other) for a given board state.
        conflicts = 0
        for row1 in range(8):
            for row2 in range(row1 + 1, 8):
                if board[row1] == board[row2]:  # Same column
                    conflicts += 1
                if abs(board[row1] - board[row2]) == abs(row1 - row2):  # Same diagonal
                    conflicts += 1
        return conflicts

    def hill_climb(self):
        # Perform simple hill climbing until we reach a solution or a local maxima.
        current_conflicts = self.calculate_conflicts(self.board)

        while True:
            # Flag to check if we find a better neighbor
            found_better = False

            # Try moving each queen (in each row) to a different column
            for row in range(8):
                original_col = self.board[row]  # Remember the original column of the queen
                for col in range(8):
                    if col != original_col:  # Move to a different column
                        new_board = self.board[:]  # Copy the current board
                        new_board[row] = col  # Move the queen to the new column
                        new_conflicts = self.calculate_conflicts(new_board)  # Calculate conflicts for the new board

                        if new_conflicts < current_conflicts:  # If we find a better board
                            self.board = new_board  # Accept the new board
                            current_conflicts = new_conflicts  # Update current conflicts
                            found_better = True  # Set the flag to true
                            break  # Move on without checking further neighbors

                if found_better:
                    break  # Move to the next iteration with the new board

            if not found_better:  # If no better neighbor was found, we are stuck
                break

        return current_conflicts == 0  # Return True if no conflicts remain (solution found)

# Example usage:
solver = EightQueens()  # Create an 8-Queens solver object
print("Initial board:")
solver.print_board()  # Print the initial random board

if solver.hill_climb():  # Run the hill climbing algorithm
    print("Solution found:")
else:
    print("Local maximum reached, no solution found:")
solver.print_board()  # Print the final board (solution or local maximum)
# Out:
# Initial board:
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . . Q
# . . Q . . . . .
# . Q . . . . . .
#
# Local maximum reached, no solution found:
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .

# %% [markdown]
# Explanation:
#
#
# ### 1. **Class Definition: `EightQueens`**
#    - The class `EightQueens` encapsulates all the methods and properties needed to solve the 8-Queens problem using the hill climbing algorithm.
#    - It contains methods for initialization, printing the board, calculating conflicts, and performing the hill climbing.
#
# ---
#
# ### 2. **Constructor: `__init__` Method**
#    - The `__init__` method initializes the board.
#    - It creates a list of 8 integers representing the column positions of the queens for each row. Each queen is randomly placed in one of the 8 columns.
#
#    ```python
#    self.board = [random.randint(0, 7) for _ in range(8)]
#    ```
#
#    - Example: If `self.board = [0, 4, 7, 5, 2, 6, 1, 3]`, it means:
#      - Row 0 has a queen in column 0,
#      - Row 1 has a queen in column 4, and so on.
#
# ---
#
# ### 3. **Printing the Board: `print_board` Method**
#    - The `print_board` method visually represents the current state of the board.
#    - It loops through each row and column and prints:
#      - `Q` for the queen's position.
#      - `.` for empty spaces.
#
#    ```python
#    def print_board(self):
#        for row in range(8):
#            line = ""
#            for col in range(8):
#                if self.board[row] == col:
#                    line += "Q "
#                else:
#                    line += ". "
#            print(line)
#        print()
#    ```
#
#    - This visualization helps to understand the placement of queens at any given time.
#
# ---
#
# ### 4. **Calculating Conflicts: `calculate_conflicts` Method**
#    - The purpose of this method is to count how many queens are attacking each other on the board.
#    - It checks for two types of conflicts:
#      - **Same Column Conflict**: Two queens in the same column.
#      - **Diagonal Conflict**: Two queens on the same diagonal (determined by the difference in their row and column positions).
#
# Let’s break down the `calculate_conflicts` method in detail. This method is crucial for evaluating how many queens on the chessboard are in a position to attack each other, which helps determine the validity of a particular board configuration in the 8-Queens problem.
#
# ### Code Explanation
#
# ```python
# def calculate_conflicts(self, board):
#     conflicts = 0
#     for row1 in range(8):
#         for row2 in range(row1 + 1, 8):
#             if board[row1] == board[row2]:  # Same column
#                 conflicts += 1
#             if abs(board[row1] - board[row2]) == abs(row1 - row2):  # Same diagonal
#                 conflicts += 1
#     return conflicts
# ```
#
# ### 4.1. **Method Definition and Initialization**
# - **Method Name**: `calculate_conflicts`
# - **Parameter**: `board`
#   - This parameter is expected to be a list of integers where each index represents a row (0 to 7) and the value at each index represents the column (0 to 7) where a queen is placed.
# - **Variable `conflicts`**:
#   - This variable is initialized to `0`. It will be used to count the number of conflicts between the queens on the board.
#
# ### 4.2. **Outer Loop: Iterating Over Rows**
# - The outer loop iterates through each queen represented by `row1`:
#
# ```python
# for row1 in range(8):
# ```
# - **`row1`**: Represents the index of the first queen being considered. This loop will go through all rows (0 to 7).
#
# ### 4.3. **Inner Loop: Comparing Against Subsequent Rows**
# - The inner loop iterates through the subsequent rows starting from `row1 + 1`:
#
# ```python
# for row2 in range(row1 + 1, 8):
# ```
# - **`row2`**: Represents the index of the second queen being compared with the queen at `row1`. This ensures that each queen is only compared with those that come after it in the list.
# - By starting from `row1 + 1`, we avoid counting conflicts for pairs of queens more than once and also avoid self-comparison.
#
# ### 4.4. **Checking for Same Column Conflicts**
# - The first conflict check examines if both queens are in the same column:
#
# ```python
# if board[row1] == board[row2]:  # Same column
#     conflicts += 1
# ```
# - **Condition**: `board[row1] == board[row2]`
#   - This checks if the columns of the queens in `row1` and `row2` are the same. If they are, it indicates a conflict.
# - **Action**: If this condition is true, the `conflicts` counter is incremented by `1`.
#
# ### 4.5. **Checking for Same Diagonal Conflicts**
# - The second conflict check examines if both queens are on the same diagonal:
#
# ```python
# if abs(board[row1] - board[row2]) == abs(row1 - row2):  # Same diagonal
#     conflicts += 1
# ```
# - **Condition**: `abs(board[row1] - board[row2]) == abs(row1 - row2)`
#   - This checks for diagonal conflicts using the properties of the coordinates:
#     - Two queens are on the same diagonal if the difference in their column positions (`abs(board[row1] - board[row2])`) is equal to the difference in their row positions (`abs(row1 - row2)`).
#     - This condition uses the absolute value function `abs()` to account for both left-diagonal and right-diagonal attacks.
# - **Action**: If this condition is true, it indicates a diagonal conflict, and the `conflicts` counter is incremented by `1`.
#
# ### 4.6. **Returning the Total Conflicts**
# - After all comparisons are made, the method returns the total count of conflicts:
#
#
# - This 'conflicts' value indicates how many pairs of queens can attack each other on the current board configuration.
#
# ### Summary of Functionality
# - The `calculate_conflicts` method systematically checks every pair of queens on the board to count how many of them can attack each other based on their positions.
# - It uses two nested loops to efficiently compare each queen against the others, checking both for column and diagonal conflicts.
# - This method is crucial for the hill climbing algorithm to evaluate the quality of different board configurations, guiding the algorithm to find a configuration with zero conflicts (a valid solution).
#
# ### Example Scenario
# Consider a board configuration represented as follows:
#
# ```python
# board = [0, 2, 4, 6, 1, 3, 5, 7]
# ```
#
# - This means:
#   - Row 0 has a queen in column 0,
#   - Row 1 has a queen in column 2,
#   - Row 2 has a queen in column 4, and so on.
#
# If we analyze the conflicts using `calculate_conflicts`:
# 1. The queens in rows 0 and 4 (columns 0 and 1) are not in the same column or diagonal.
# 2. The queens in rows 1 and 5 (columns 2 and 3) are also not in the same column or diagonal.
# 3. However, if we check queens in rows 0 and 2 (columns 0 and 4), they are neither in the same column nor diagonal, so no conflicts there.
#
# After checking all pairs, the function returns the total number of conflicts, allowing the algorithm to decide on the next moves based on this information.
#
# ---
#
# ### 5. **Hill Climbing Algorithm: `hill_climb` Method**
#    - This method implements the simple hill climbing algorithm to find a solution to the 8-Queens problem.
#
#    ```python
#    def hill_climb(self):
#        current_conflicts = self.calculate_conflicts(self.board)
#    ```
#
#    - **Initialization**: It starts by calculating the current number of conflicts for the initial board.
#
# ---
#
# #### 5.1 **Main Loop**
#    - The algorithm enters a loop that continues until no better state is found (i.e., it reaches a local maximum).
#
#    ```python
#    while True:
#        found_better = False  # Flag to check if we find a better neighbor
#    ```
#
#    - The `found_better` flag is initialized to `False` at the beginning of each iteration.
#
# ---
#
# #### 5.2 **Evaluating Neighbors**
#    - The algorithm tries to improve the current board by checking each queen's possible moves (to different columns).
#
#    ```python
#    for row in range(8):
#        original_col = self.board[row]  # Remember the original column of the queen
#        for col in range(8):
#            if col != original_col:  # Move to a different column
#                new_board = self.board[:]  # Copy the current board
#                new_board[row] = col  # Move the queen to the new column
#                new_conflicts = self.calculate_conflicts(new_board)  # Calculate conflicts for the new board
#    ```
#
#    - It loops through each row and attempts to move the queen to each column except its current position.
#    - A copy of the current board is created (`new_board`), and the new conflicts are calculated after moving the queen.
#
# ---
#
# #### 5.3 **Accepting Better Neighbor**
#    - If the new board has fewer conflicts than the current board, the algorithm accepts this new configuration.
#
#    ```python
#    if new_conflicts < current_conflicts:  # If we find a better board
#        self.board = new_board  # Accept the new board
#        current_conflicts = new_conflicts  # Update current conflicts
#        found_better = True  # Set the flag to true
#        break  # Move on without checking further neighbors
#    ```
#
#    - It updates the current board and conflict count and sets `found_better` to `True`.
#    - The inner loop breaks so the algorithm can restart checking for a better state.
#
# ---
#
# #### 5.4 **Stopping Condition**
#    - If no better neighbor is found after checking all possibilities (the flag remains `False`), the algorithm exits the loop.
#
#    ```python
#    if not found_better:  # If no better neighbor was found, we are stuck
#        break
#    ```
#
# ---
#
# #### 5.5 **Returning the Result**
#    - Finally, the method checks if the current state is a valid solution by seeing if the conflict count is zero.
#
#    ```python
#    return current_conflicts == 0  # Return True if no conflicts remain (solution found)
#    ```
#
#    - It returns `True` if a solution is found (no conflicts) or `False` if it stops at a local maximum.
#
# ---
#
# ### 6. **Example Usage**
#    - The example usage demonstrates how to create an instance of the `EightQueens` class and run the hill climbing algorithm.
#
#    ```python
#    solver = EightQueens()  # Create an 8-Queens solver object
#    print("Initial board:")
#    solver.print_board()  # Print the initial random board
#
#    if solver.hill_climb():  # Run the hill climbing algorithm
#        print("Solution found:")
#    else:
#        print("Local maximum reached, no solution found:")
#    solver.print_board()  # Print the final board (solution or local maximum)
#    ```
#
#    - It initializes the solver, prints the random starting board, attempts to find a solution, and prints the result.
#
# ---
#
# ### Summary:
# - The **8-Queens problem** is solved using a **simple hill climbing algorithm**.
# - The algorithm initializes a random board, calculates conflicts, and iteratively moves queens to reduce conflicts.
# - It accepts the first improvement it finds, continuing until it either finds a solution or reaches a local maximum.
# - The program provides a visual representation of the board, making it easier for students to understand the placements and the process of solving the problem.

# %% [markdown]
# **Random Restart Hill Climbing Algorithm ( a variant of hill climbing algorithm)**

# %%
import random

class EightQueens:
    def __init__(self):
        # Initialize the board with one queen in each row, placed randomly in one of the columns.
        self.board = [random.randint(0, 7) for _ in range(8)]

    def print_board(self):
        # Print the board for visualization
        for row in range(8):
            line = ""
            for col in range(8):
                if self.board[row] == col:
                    line += "Q "
                else:
                    line += ". "
            print(line)
        print()

    def calculate_conflicts(self, board):
        # Calculate the number of conflicts (queens attacking each other) for a given board state.
        conflicts = 0
        for row1 in range(8):
            for row2 in range(row1 + 1, 8):
                if board[row1] == board[row2]:  # Same column
                    conflicts += 1
                if abs(board[row1] - board[row2]) == abs(row1 - row2):  # Same diagonal
                    conflicts += 1
        return conflicts

    def hill_climb(self):
        # Perform simple hill climbing until we reach a solution or a local maximum.
        current_conflicts = self.calculate_conflicts(self.board)

        while True:
            # Flag to check if we find a better neighbor
            found_better = False

            # Try moving each queen (in each row) to a different column
            for row in range(8):
                original_col = self.board[row]  # Remember the original column of the queen
                for col in range(8):
                    if col != original_col:  # Move to a different column
                        new_board = self.board[:]  # Copy the current board
                        new_board[row] = col  # Move the queen to the new column
                        new_conflicts = self.calculate_conflicts(new_board)  # Calculate conflicts for the new board

                        if new_conflicts < current_conflicts:  # If we find a better board
                            self.board = new_board  # Accept the new board
                            current_conflicts = new_conflicts  # Update current conflicts
                            found_better = True  # Set the flag to true
                            break  # Move on without checking further neighbors

                if found_better:
                    break  # Move to the next iteration with the new board

            if not found_better:  # If no better neighbor was found, we are stuck
                break

        return current_conflicts == 0  # Return True if no conflicts remain (solution found)

    def random_restart_hill_climb(self, max_restarts=100):
        # Perform random-restart hill climbing to find a solution.
        restart_count = 0

        while restart_count < max_restarts:
            if self.hill_climb():  # Try to find a solution with hill climbing
                return True  # Solution found

            # If hill climbing fails, perform a random restart
            print(f"Restarting... ({restart_count + 1})")
            self.board = [random.randint(0, 7) for _ in range(8)]  # Generate a new random board
            restart_count += 1

        return False  # Return False if the maximum number of restarts is reached without finding a solution


# Example usage:
solver = EightQueens()  # Create an 8-Queens solver object

if solver.random_restart_hill_climb():  # Run the random-restart hill climbing algorithm
    print("Solution found:")
else:
    print("No solution found within the given number of restarts.")
solver.print_board()  # Print the final board (solution or local maximum)
# Out:
# Restarting... (1)
# Restarting... (2)
# Solution found:
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .

# %% [markdown]
# Explanation of the random restart aspect of the above code:
#
# ---
#
# ### 1. **Random Restart Method: `random_restart_hill_climb`**
#    - This method is responsible for executing the random restart hill climbing process.
#    - It attempts to solve the 8-Queens problem by repeatedly using the simple hill climbing algorithm and generating new random boards when necessary.
#
#    ```python
#    def random_restart_hill_climb(self, max_restarts=100):
#        restart_count = 0
#    ```
#
#    - The method accepts an optional parameter `max_restarts`, which specifies the maximum number of times the algorithm will restart in search of a solution. The default value is set to 100.
#
# ---
#
# ### 2. **Loop for Restart Attempts**
#    - A while loop runs as long as the number of restarts is less than `max_restarts`.
#
#    ```python
#    while restart_count < max_restarts:
#    ```
#
#    - This loop allows the algorithm to attempt hill climbing from different starting points (randomly generated boards) up to the specified limit.
#
# ---
#
# ### 3. **Attempting Hill Climbing**
#    - Inside the loop, the method calls `self.hill_climb()` to try to find a solution using the hill climbing algorithm.
#
#    ```python
#    if self.hill_climb():  # Try to find a solution with hill climbing
#        return True  # Solution found
#    ```
#
#    - If the `hill_climb()` method returns `True`, indicating that a solution was found (no conflicts), the `random_restart_hill_climb()` method also returns `True`, signaling success.
#
# ---
#
# ### 4. **Handling Local Maxima**
#    - If the hill climbing attempt does not find a solution, it means the algorithm reached a local maximum (i.e., no better state could be found).
#
#    ```python
#    print(f"Restarting... ({restart_count + 1})")
#    ```
#
#    - The program prints a message indicating that it will restart with a new random board and shows the restart count.
#
# ---
#
# ### 5. **Generating a New Random Board**
#    - After printing the restart message, the method generates a new random board by placing queens in random columns for each row.
#
#    ```python
#    self.board = [random.randint(0, 7) for _ in range(8)]  # Generate a new random board
#    ```
#
#    - This resets the state of the board to a new configuration, allowing the hill climbing algorithm to start fresh.
#
# ---
#
# ### 6. **Incrementing Restart Count**
#    - The `restart_count` variable is incremented to keep track of how many times the algorithm has restarted.
#
#    ```python
#    restart_count += 1
#    ```
#
#    - This ensures that the loop will eventually terminate if no solution is found within the specified number of restarts.
#
# ---
#
# ### 7. **Completion of Attempts**
#    - After the loop, if no solution was found after all restart attempts, the method returns `False`.
#
#    ```python
#    return False  # Return False if the maximum number of restarts is reached without finding a solution
#    ```
#
#    - This indicates that the algorithm could not find a valid configuration of queens within the given restart limit.
#
# ---
#
# ### 8. **Example Usage**
#    - The example usage in the main program calls this new method to execute the random restart hill climbing algorithm.
#
#    ```python
#    if solver.random_restart_hill_climb():  # Run the random-restart hill climbing algorithm
#        print("Solution found:")
#    else:
#        print("No solution found within the given number of restarts.")
#    ```
#
#    - It attempts to find a solution using the `random_restart_hill_climb()` method and prints whether a solution was found or not.
#
# ---
#
# ### Summary:
# - The **random restart mechanism** enhances the **hill climbing** algorithm by allowing it to escape local maxima through multiple attempts with different initial configurations.
# - By randomly reinitializing the board, the algorithm increases its chances of finding a valid solution for the 8-Queens problem.
# - This method effectively combines the strengths of randomization with local search, making it a powerful approach to tackling optimization problems where the search space may contain numerous local optima.
